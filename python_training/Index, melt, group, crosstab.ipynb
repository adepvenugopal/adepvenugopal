# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv('nyc_weather.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %% [markdown]
# <font color='blue'>**Lambda function**</font>

# %%
df.Temperature.head()
# Out:
# 0    38
# 1    36
# 2    40
# 3    25
# 4    20
# Name: Temperature, dtype: int64

# %%
df.Temperature.apply(lambda x : x/2).head()
# Out:
# 0    19.0
# 1    18.0
# 2    20.0
# 3    12.5
# 4    10.0
# Name: Temperature, dtype: float64

# %% [markdown]
# <font color='blue'>**Primary and Secondary Indexes**</font>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint   ...    Events  WindDirDegrees  HumDew
# 0  1/1/2016           38        23   ...       NaN             281      75
# 1  1/2/2016           36        18   ...       NaN             275      64
# 2  1/3/2016           40        21   ...       NaN             277      68
# 3  1/4/2016           25         9   ...       NaN             345      53
# 4  1/5/2016           20        -3   ...       NaN             333      38
#
# [5 rows x 12 columns]

# %%
df1 = df.set_index(["EST"])
df1.head()
# Out:
#           Temperature  DewPoint  Humidity   ...    Events  WindDirDegrees  HumDew
# EST                                         ...
# 1/1/2016           38        23        52   ...       NaN             281      75
# 1/2/2016           36        18        46   ...       NaN             275      64
# 1/3/2016           40        21        47   ...       NaN             277      68
# 1/4/2016           25         9        44   ...       NaN             345      53
# 1/5/2016           20        -3        41   ...       NaN             333      38
#
# [5 rows x 11 columns]

# %%
df1 = df.set_index(["Events", "VisibilityMiles"])
df1
# Out:
#                                 EST  Temperature   ...    WindDirDegrees  HumDew
# Events   VisibilityMiles                           ...
# NaN      10                1/1/2016           38   ...               281      75
#          10                1/2/2016           36   ...               275      64
#          10                1/3/2016           40   ...               277      68
#          10                1/4/2016           25   ...               345      53
#          10                1/5/2016           20   ...               333      38
#          10                1/6/2016           33   ...               259      39
#          10                1/7/2016           39   ...               293      44
#          10                1/8/2016           39   ...                79      93
# Rain     9                 1/9/2016           44   ...                76     115
#          4                1/10/2016           50   ...               109     117
# ...

# %% [markdown]
# <font color='blue'>**Melting DataFrames**</font>

# %%
pd.melt(df, id_vars="Temperature", value_vars=["DewPoint", "Humidity"]).head()
# Out:
#    Temperature  variable  value
# 0           38  DewPoint     23
# 1           36  DewPoint     18
# 2           40  DewPoint     21
# 3           25  DewPoint      9
# 4           20  DewPoint     -3

# %%
df.Temperature.head()
# Out:
# 0    38
# 1    36
# 2    40
# 3    25
# 4    20
# Name: Temperature, dtype: int64

# %%
df.DewPoint.head()
# Out:
# 0    23
# 1    18
# 2    21
# 3     9
# 4    -3
# Name: DewPoint, dtype: int64

# %%
df.Humidity.head()
# Out:
# 0    52
# 1    46
# 2    47
# 3    44
# 4    41
# Name: Humidity, dtype: int64

# %% [markdown]
# <font color='blue'>**Groupby function**</font>

# %%
df.groupby('Events').count()
# Out:
#           EST  Temperature  DewPoint   ...    CloudCover  WindDirDegrees  HumDew
# Events                                 ...
# Fog-Snow    2            2         2   ...             2               2       2
# Rain        4            4         4   ...             4               4       4
# Snow        3            3         3   ...             3               3       3
#
# [3 rows x 11 columns]

# %%
df.groupby('Events').sum()
# Out:
#           Temperature  DewPoint   ...    WindDirDegrees  HumDew
# Events                            ...
# Fog-Snow           62        44   ...               387     188
# Rain              182       143   ...               836     406
# Snow               79        23   ...               654     170
#
# [3 rows x 9 columns]

# %%
df.groupby('Events').sum()[['Temperature', 'DewPoint']]
# Out:
#           Temperature  DewPoint
# Events
# Fog-Snow           62        44
# Rain              182       143
# Snow               79        23

# %%
df.groupby('Events').sum()[['Temperature', 'DewPoint']].max()
# Out:
# Temperature    182
# DewPoint       143
# dtype: int64

# %% [markdown]
# <h1 style="color:blue" align="center">////// Crosstab Tutorial ////// </h1>

# %% [markdown]
# <h2 style="color:purple">Crosstabs</h2>

# %%
pd.crosstab(df.Events, df.Temperature)
# Out:
# Temperature  25  26  28  36  41  44  47  50
# Events
# Fog-Snow      0   1   0   1   0   0   0   0
# Rain          0   0   0   0   1   1   1   1
# Snow          1   1   1   0   0   0   0   0

# %%
pd.crosstab(df.CloudCover, df.Events)
# Out:
# Events      Fog-Snow  Rain  Snow
# CloudCover
# 2                  0     0     1
# 3                  0     1     2
# 6                  1     0     0
# 7                  0     2     0
# 8                  1     1     0

# %% [markdown]
# <h2 style="color:purple">Margins</h2>

# %%
pd.crosstab(df.Events, df.Temperature, margins=True)
# Out:
# Temperature  25  26  28  36  41  44  47  50  All
# Events
# Fog-Snow      0   1   0   1   0   0   0   0    2
# Rain          0   0   0   0   1   1   1   1    4
# Snow          1   1   1   0   0   0   0   0    3
# All           1   2   1   1   1   1   1   1    9

# %% [markdown]
# <h2 style="color:purple">Multi Index Column and Rows</h2>

# %%
pd.crosstab(df.Events, [df.Temperature,df.VisibilityMiles], margins=True)
# Out:
# Temperature     25 26    28 36 41 44 47 50 All
# VisibilityMiles  9  1  9  8  8 10  9  8  4
# Events
# Fog-Snow         0  1  0  0  1  0  0  0  0   2
# Rain             0  0  0  0  0  1  1  1  1   4
# Snow             1  0  1  1  0  0  0  0  0   3
# All              1  1  1  1  1  1  1  1  1   9

# %% [markdown]
# <h2 style="color:purple">Normalize</h2>

# %%
pd.crosstab(df.Events, df.Temperature, normalize='index')
# Out:
# Temperature        25        26        28   36    41    44    47    50
# Events
# Fog-Snow     0.000000  0.500000  0.000000  0.5  0.00  0.00  0.00  0.00
# Rain         0.000000  0.000000  0.000000  0.0  0.25  0.25  0.25  0.25
# Snow         0.333333  0.333333  0.333333  0.0  0.00  0.00  0.00  0.00

# %% [markdown]
# <h2 style="color:purple">Aggfunc and Values</h2>

# %%
pd.crosstab(df.Events, df.Temperature, values=df.DewPoint, aggfunc=np.average)
# Out:
# Temperature   25    26    28    36    41    44    47    50
# Events
# Fog-Snow     NaN  21.0   NaN  23.0   NaN   NaN   NaN   NaN
# Rain         NaN   NaN   NaN   NaN  22.0  38.0  37.0  46.0
# Snow         6.0   6.0  11.0   NaN   NaN   NaN   NaN   NaN
