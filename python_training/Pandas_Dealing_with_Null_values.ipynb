# %% [markdown]
# # **Import Packages**

# %%
#Import pandas package
import pandas as pd

# %% [markdown]
# # **Import Data**

# %%
#Read nyc_weather.csv into df
df = pd.read_csv('nyc_weather.csv')

# %% [markdown]
# # Dealing with Null Values

# %% [markdown]
# **NULL values in ANY column?  TRUE/FALSE**

# %%
#Find if there are any null values in columns
df.isnull().any()
# Out:
# EST                     False
# Temperature             False
# DewPoint                False
# Humidity                False
# Sea Level PressureIn    False
# VisibilityMiles         False
# WindSpeedMPH             True
# PrecipitationIn         False
# CloudCover              False
# Events                   True
# WindDirDegrees          False
# dtype: bool

# %% [markdown]
# **NULL value in ANY Cell?  TRUE/FALSE**

# %%
df.isnull()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   False        False     False     False                 False
# 1   False        False     False     False                 False
# 2   False        False     False     False                 False
# 3   False        False     False     False                 False
# 4   False        False     False     False                 False
# 5   False        False     False     False                 False
# 6   False        False     False     False                 False
# 7   False        False     False     False                 False
# 8   False        False     False     False                 False
# 9   False        False     False     False                 False
# 10  False        False     False     False                 False
# 11  False        False     False     False                 False
# 12  False        False     False     False                 False
# ...

# %% [markdown]
# **ROWS with NULL value in WindSpeedMPH column**

# %%
#Show only the rows which have Null values in WindSpeedMPH column
df[df.WindSpeedMPH.isnull()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 21  1/22/2016           26         6        41                 30.21
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                 4           NaN             1.8           7   Rain
# 10               10           NaN               0           1    NaN
# 21                9           NaN            0.01           3   Snow
#
#     WindDirDegrees
# 9              109
# 10             289
# 21              34

# %% [markdown]
# **ROWS with NULL value in EVENTS column**

# %%
#Show only the rows which have Null values in Events column
df[df.Events.isnull()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# ...

# %% [markdown]
# <font color='blue'>**Find count of null values for each field**</font>

# %%
df.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %% [markdown]
# <font color='blue'>**Find the rows which have null values for the field WindSpeedMPH**</font>

# %%
df[df['WindSpeedMPH'].isnull()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 21  1/22/2016           26         6        41                 30.21
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                 4           NaN             1.8           7   Rain
# 10               10           NaN               0           1    NaN
# 21                9           NaN            0.01           3   Snow
#
#     WindDirDegrees
# 9              109
# 10             289
# 21              34

# %% [markdown]
# <font color='blue'>**Find the rows which have null values for the field Events**</font>

# %%
df[df['Events'].isnull()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# ...

# %% [markdown]
# **ROWS with NULL value in WindSpeedMPH and Events column**

# %%
#Show only the rows which have Null values in WindSpeedMPH and Events columns
df[df.WindSpeedMPH.isnull() & df.Events.isnull()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 10  1/11/2016           33         8        37                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 10               10           NaN               0           1    NaN
#
#     WindDirDegrees
# 10             289

# %% [markdown]
# **DROP the ROWS IF ANY column has NULL value**

# %%
df1 = df.dropna(how='any')
df1
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# ...

# %%
df1 = df.dropna(how='all')
df1
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#Fill the null values with zero
df.fillna(0)
#df.fillna(0, inplace=True)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df2=df.dropna(how='all')
df2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#Show only the rows which have Null values
df1.isnull()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   False        False     False     False                 False
# 1   False        False     False     False                 False
# 2   False        False     False     False                 False
# 3   False        False     False     False                 False
# 4   False        False     False     False                 False
# 5   False        False     False     False                 False
# 6   False        False     False     False                 False
# 7   False        False     False     False                 False
# 8   False        False     False     False                 False
# 9   False        False     False     False                 False
# 10  False        False     False     False                 False
# 11  False        False     False     False                 False
# 12  False        False     False     False                 False
# ...

# %%
df1.fillna(0)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#Recheck if null values exist
df.isnull().any()
# Out:
# EST                     False
# Temperature             False
# DewPoint                False
# Humidity                False
# Sea Level PressureIn    False
# VisibilityMiles         False
# WindSpeedMPH             True
# PrecipitationIn         False
# CloudCover              False
# Events                   True
# WindDirDegrees          False
# dtype: bool

# %%
#Display all the rows where "temperature" > 40
df[df['Temperature'] > 40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
#Display the day where temperature is the maximum temperature
df['EST'][df['Temperature'] == df['Temperature'].max()]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
# Display the row where the "teperature" is equal to max temperature
df [ df['Temperature'] == df['Temperature'].max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
#Display standard deviation of temperature
df['Temperature'].std()
# Out:
# 7.639315400279415

# %%
#Find basic statistics like count, mean, std. dev, min, max etc (all the numerical fields in dataframe)
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
#Find basic statistics like count, mean, std. dev, min, max etc (specific column)
df.Temperature.describe()
# Out:
# count    31.000000
# mean     34.677419
# std       7.639315
# min      20.000000
# 25%      29.000000
# 50%      35.000000
# 75%      39.500000
# max      50.000000
# Name: Temperature, dtype: float64

# %%
#Make "EST" field as index column (temporarily)
df.set_index('EST')
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
#Confirm that index is not changed in the dataframe df
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
#Make "EST" field as index column (permanently)
df.set_index('EST', inplace=True)

# %%
#Confirm that index is changed
df.head()
# Out:
#           Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016           38        23        52                 30.03
# 1/2/2016           36        18        46                 30.02
# 1/3/2016           40        21        47                 29.86
# 1/4/2016           25         9        44                 30.05
# 1/5/2016           20        -3        41                 30.57
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/1/2016               10           8.0               0           5    NaN
# 1/2/2016               10           7.0               0           3    NaN
# 1/3/2016               10           8.0               0           1    NaN
# 1/4/2016               10           9.0               0           3    NaN
# 1/5/2016               10           5.0               0           0    NaN
#
#           WindDirDegrees
# EST
# 1/1/2016             281
# 1/2/2016             275
# 1/3/2016             277
# ...

# %%
#Display index column
df.index
# Out:
# Index(['1/1/2016', '1/2/2016', '1/3/2016', '1/4/2016', '1/5/2016', '1/6/2016',
#        '1/7/2016', '1/8/2016', '1/9/2016', '1/10/2016', '1/11/2016',
#        '1/12/2016', '1/13/2016', '1/14/2016', '1/15/2016', '1/16/2016',
#        '1/17/2016', '1/18/2016', '1/19/2016', '1/20/2016', '1/21/2016',
#        '1/22/2016', '1/23/2016', '1/24/2016', '1/25/2016', '1/26/2016',
#        '1/27/2016', '1/28/2016', '1/29/2016', '1/30/2016', '1/31/2016'],
#       dtype='object', name='EST')

# %%
#Display row elements by Index name
df.loc['1/2/2016']
# Out:
# Temperature                36
# DewPoint                   18
# Humidity                   46
# Sea Level PressureIn    30.02
# VisibilityMiles            10
# WindSpeedMPH                7
# PrecipitationIn             0
# CloudCover                  3
# Events                    NaN
# WindDirDegrees            275
# Name: 1/2/2016, dtype: object

# %%
#Display row elements by Index name
df.loc[['1/2/2016', '1/13/2016', '1/30/2016']]
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/2/2016            36        18        46                 30.02
# 1/13/2016           26         4        42                 29.94
# 1/30/2016           34        16        46                 30.01
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/2/2016                10           7.0               0           3    NaN
# 1/13/2016               10          10.0               0           0    NaN
# 1/30/2016               10           7.0               0           0    NaN
#
#            WindDirDegrees
# EST
# 1/2/2016              275
# 1/13/2016             284
# 1/30/2016             257

# %%
#Display row elements by Index number
df.iloc[2]
# Out:
# Temperature                40
# DewPoint                   21
# Humidity                   47
# Sea Level PressureIn    29.86
# VisibilityMiles            10
# WindSpeedMPH                8
# PrecipitationIn             0
# CloudCover                  1
# Events                    NaN
# WindDirDegrees            277
# Name: 1/3/2016, dtype: object

# %%
#Display specific row elements by Index number
df.iloc[[2,6,10]]
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/3/2016            40        21        47                 29.86
# 1/7/2016            39        11        33                 30.28
# 1/11/2016           33         8        37                 29.92
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/3/2016                10           8.0               0           1    NaN
# 1/7/2016                10           2.0               0           3    NaN
# 1/11/2016               10           NaN               0           1    NaN
#
#            WindDirDegrees
# EST
# 1/3/2016              277
# 1/7/2016              293
# 1/11/2016             289

# %%
#Reset index to default
df.reset_index(inplace=True)

# %%
#Replace the column value with different value.
df['Events'].replace('Rain', 'Rainy')
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8        Rainy
# 9        Rainy
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15       Rainy
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26       Rainy
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
#Confirm that index is reset to default
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %% [markdown]
# <font color='blue'>**Find the count of each Event**</font>

# %%
#Find the count of each category
df.Events.value_counts()
# Out:
# Rain        4
# Snow        3
# Fog-Snow    2
# Name: Events, dtype: int64

# %% [markdown]
# <font color='blue'>**Find the count of each Event including Null values**</font>

# %%
df['Events'].value_counts(dropna=False)
# Out:
# NaN         22
# Rain         4
# Snow         3
# Fog-Snow     2
# Name: Events, dtype: int64

# %% [markdown]
# <font color='blue'>**Find the unique values in the given column**</font>

# %%
df['Events'].unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df['VisibilityMiles'].unique()
# Out:
# array([10,  9,  4,  8,  1], dtype=int64)

# %% [markdown]
# <font color='blue'>**Slicing rows and columns**</font>

# %%
df.loc[1:5,'EST':'DewPoint']
# Out:
#         EST  Temperature  DewPoint
# 1  1/2/2016           36        18
# 2  1/3/2016           40        21
# 3  1/4/2016           25         9
# 4  1/5/2016           20        -3
# 5  1/6/2016           33         4
