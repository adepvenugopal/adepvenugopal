# %% [markdown]
# # **Import packages**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Open the URL of the website to be scraped

# %%
html = urlopen('http://www.iitb.ac.in')

# %% [markdown]
# # Display the contents of the websites

# %%
html.read()
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->\n  <head>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="shortcut icon" href="http://www.iitb.ac.in/sites/default/files/favicon_0_0.ico" type="image/vnd.microsoft.icon" />\n    <title>IIT Bombay | IIT Bombay</title>\n<link href=\'//fonts.googleapis.com/css?family=Source+Sans+Pro:400,600|Oswald\' rel=\'stylesheet\' type=\'text/css\'>\n    <style type="text/css" media="all">\n@import url("http://www.iitb.ac.in/modules/system/system.base.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/system/system.menus.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/system/system.messages.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/system/system.theme.css?poejo8");\n</style>\n<style type="text/css" media="all">\n@import url("http://www.iitb.ac.in/sites/all/libraries/mediaelement/build/mediaelementplayer.min.css?poejo8");\n</style>\n<style type="text/css" media="all">\n@import url("http://www.iitb.ac.in/sites/all/modules/ldap/ldap_user/ldap_user.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/calendar/css/calendar_multiday.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/comment/comment.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/date/date_api/date.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/date/date_popup/themes/datepicker.1.7.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/field/theme/field.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/node/node.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/search/search.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/user/user.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/views/css/views.css?poejo8");\n</style>\n<style type="text/css" media="all">\n@import url("http://www.iitb.ac.in/sites/all/modules/ed_classified/theme/classified.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/ctools/css/ctools.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/dhtml_menu/dhtml_menu.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/ldap/ldap_servers/ldap_servers.admin.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/modules/panels/css/panels.css?poejo8");\n@import url("http://www.iitb.ac.in/modules/locale/locale.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/themes/touchm/../../../../sites/all/themes/touchm/stylesheets/foundation.min.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/themes/touchm/../../../../sites/all/themes/touchm/stylesheets/common-style.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/themes/touchm/stylesheets/color5.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/themes/touchm/../../../../sites/all/themes/touchm/plugins/titan/css/jquery.titanlighbox.css?poejo8");\n@import url("http://www.iitb.ac.in/sites/all/themes/touchm/../../../../sites/all/themes/touchm/stylesheets/touchm.css?poejo8");\n</style>\n        <script src="http://www.iitb.ac.in/misc/jquery.js"> </script>\n\n    <!--script> src="/misc/jquery.once.js" </script-->\n\n    <!--[if lt IE 9]>\n      <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n    <![endif]-->\n  </head>\n  <body class="html front not-logged-in one-sidebar sidebar-second page-node i18n-en" >\n    <div id="skip-link">\n      <a href="#main-content" class="element-invisible element-focusable">Skip to main content</a>\n    </div>\n        <script src="/sites/all/libraries/tables ...

# %% [markdown]
# # Beautify the contents of website and display

# %%
bs = BeautifulSoup(html.read(), 'html.parser')
print(bs)

# %% [markdown]
# # Display the headers

# %%
print(bs.h1)
print(bs.h2)
print(bs.h3)
# Out:
# None
# None
# None

# %% [markdown]
# # Display titles News & Events section

# %%
nameList = bs.findAll('div', {'class': 'views-field views-field-title'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# # Display details in the News section

# %%
nameList = bs.findAll('div', {'class': 'views-field views-field-body'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# # Display "Research Highlights" section

# %%
nameList = bs.findAll('div', {'class': 'work-item-content'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# # Display "Footer" section

# %%
nameList = bs.findAll('li', {'class': 'leaf'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# # Display Menu items and Menu listing

# %%
nameList = bs.findAll('ul', {'class': 'menu'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# # Display all the URL links on the homepage

# %%
for link in bs.findAll('a', attrs={'href': re.compile("^http://")}):
    print(link.get('href'))
